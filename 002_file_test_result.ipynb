# %%
import json
import os
import pandas as pd

# %%
results_json_path = "output/resultados.json"
df = pd.read_json(results_json_path, orient="index").reset_index()
df.columns = ["item", "value"]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   item    15 non-null     object
#  1   value   15 non-null     object
# dtypes: object(2)
# memory usage: 368.0+ bytes

# %%
# df.query("item == 'definitionName'")
columns = df["item"].tolist()
dft = df.T
dft.columns = columns
extra_cols = ["metrics", "checks", "queries", "logs"]
dflv1 = dft[[col for col in columns if col not in extra_cols]].iloc[1:,:]
dflv1

metrics_df = dft["metrics"]
pd.DataFrame(metrics_df["value"])
# Out:
#                                             identity       metricName  \
# 0  metric-test-dask-emoji-"User Age"-invalid_coun...    invalid_count
# 1                   metric-test-dask-emoji-row_count        row_count
# 2              metric-test-dask-emoji-"User Age"-avg              avg
# 3       metric-test-dask-emoji-Emoji-duplicate_count  duplicate_count
# 4                      metric-test-dask-emoji-schema           schema
#
#                                                value dataSourceName tableName  \
# 0                                               2479           dask       NaN
# 1                                               5000           dask       NaN
# 2                                            38.8756           dask       NaN
# 3                                               None           dask       NaN
# 4  [{'columnName': 'Emoji', 'sourceDataType': 'va...           dask     emoji
#
#    partitionName  columnName
# 0            NaN         NaN
# ...

# %%
df
# Out:
#                                                                            0
# definitionName                                                          test
# defaultDataSource                                                       dask
# dataTimestamp                                      2024-08-01T21:12:41+00:00
# scanStartTimestamp                                 2024-08-01T21:12:41+00:00
# scanEndTimestamp                                   2024-08-01T21:12:41+00:00
# hasErrors                                                               True
# hasWarnings                                                            False
# hasFailures                                                             True
# metrics                    [{'identity': 'metric-test-dask-emoji-"User Ag...
# checks                     [{'identity': 'dc01c375', 'name': 'row_count >...
# queries                    [{'name': '17.dask.emoji.aggregation[0]', 'dat...
# ...

# %%
df.T["checks"][0][1]
# Out:
# {'identity': '18443545',
#  'name': 'Find forbidden, missing, or wrong type',
#  'type': 'generic',
#  'definition': 'checks for emoji:\n  - schema:\n      name: Find forbidden, missing, or wrong type\n      warn:\n        when required column missing: [Emoji, "User Gender"]\n        when forbidden column present: [credit_card]\n        when wrong column type:\n          Platform: varchar\n      fail:\n        when forbidden column present: [pii*]\n        when wrong column index:\n          "User Age": 1\n',
#  'resourceAttributes': [],
#  'location': {'filePath': 'sodacl_string.yml', 'line': 10, 'col': 7},
#  'dataSource': 'dask',
#  'table': 'emoji',
#  'filter': None,
#  'column': None,
#  'metrics': ['metric-test-dask-emoji-schema'],
#  'outcome': 'fail',
#  'outcomeReasons': [],
#  'archetype': None,
#  'diagnostics': {'blocks': [{'type': 'csv',
#     'text': 'Column,Type\nEmoji,varchar\nContext,varchar\nPlatform,varchar\nUser Age,bigint\nUser Gender,varchar',
# ...
